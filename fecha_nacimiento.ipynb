# %% [markdown]
# <a href="https://colab.research.google.com/github/isleniamorales-star/CursoF5/blob/main/fecha_nacimiento.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nombre =input("Cual es tu nombre: ")
nacimiento = int(input("Cuál es tu año de nacimiento: "))
edad = 2026 - int(nacimiento)
print(f"Hola {nombre} Naciste en: {nacimiento} tienes {edad} años")
# Out:
# Cual es tu nombre: ana
# Cuál es tu año de nacimiento: 2006
# Hola ana Naciste en: 2006 tienes 20 años
