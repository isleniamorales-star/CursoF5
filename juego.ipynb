# %% [markdown]
# <a href="https://colab.research.google.com/github/isleniamorales-star/CursoF5/blob/main/juego.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

def juego_adivinanza():
  numero_secreto = random.randint(1, 100)
  intentos = 0
  adivinado = False

  print("Bienvenido al juego de adivinanzas!")
  print("Estoy pensando en un numero del 1 al 100")

  while not adivinado:
    experimento = int(input("Adivina el numero: "))
    intentos += 1

    if experimento < numero_secreto:
      print("El numero es mayor.")
    elif experimento > numero_secreto:
      print("El numero es menor")
    else:
      adivinado = True
      print(f"Felicidades adivinaste el numero en {intentos} intentos")

juego_adivinanza()
# Out:
# Bienvenido al juego de adivinanzas!
# Estoy pensando en un numero del 1 al 100
# Adivina el numero: 45
# El numero es mayor.
# Adivina el numero: 60
# El numero es mayor.
# Adivina el numero: 80
# El numero es menor
# Adivina el numero: 75
# El numero es menor
# Adivina el numero: 70
# El numero es mayor.
# Adivina el numero: 72
# El numero es menor
# Adivina el numero: 71
# Felicidades adivinaste el numero en 7 intentos
