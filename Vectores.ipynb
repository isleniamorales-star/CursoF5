# %% [markdown]
# <a href="https://colab.research.google.com/github/isleniamorales-star/CursoF5/blob/main/Vectores.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math

# Lista de vectores [x, y] de los enemigos
enemigos = [
    [3, 4],   # Enemigo A
    [1, 1],   # Enemigo B
    [0, 5],   # Enemigo C
    [8, 6]    # Enemigo D
]

print("--- REPORTE DEL RADAR ---")

for i, pos in enumerate(enemigos):
    x = pos[0]
    y = pos[1]

    # Aplicamos Pitágoras: raíz de (x² + y²)
    distancia = math.sqrt(x**2 + y**2)
    if distancia < 2:
        print(f"Enemigo {i+1}: Posición {pos} -> Distancia: {distancia:.2f} Enemigo cerca")
    else:
       print(f"Enemigo {i+1}: Posición {pos} -> Distancia: {distancia:.2f}")
# Out:
# --- REPORTE DEL RADAR ---
# Enemigo 1: Posición [3, 4] -> Distancia: 5.00
# Enemigo 2: Posición [1, 1] -> Distancia: 1.41 Enemigo cerca
# Enemigo 3: Posición [0, 5] -> Distancia: 5.00
# Enemigo 4: Posición [8, 6] -> Distancia: 10.00

# %%
  # Verificar si está cerca
    if distancia < 2:
        estado = "⚠️ ENEMIGO CERCA"
    else:
        estado = "Lejano"
